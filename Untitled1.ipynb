# %%
# linear algebra
import numpy as np

# data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
import matplotlib as plt
import matplotlib.pyplot as plt
import os

# %%
weather = pd.read_csv("bataAssignmentPy.csv")
weather
weather.head(10)
# Out:
#    waterLevel  humidity  temperature  windSpeed  clouds pedictedWeather  \
# 0           2         7           13         27      15           Rains
# 1           0        20            8         31      70          Clouds
# 2          46        12            1         18      58           Sunny
# 3          24        17            0         27      11           Rains
# 4          26         4           13         23      11          Clouds
# 5          66         1            3         11       3          Clouds
# 6           4        28           13         25      40           Sunny
# 7          45        38           10          9      44          Clouds
# 8          45         2           16         18      32          Clouds
# 9          68        24            6         30      48          Clouds
#
#    predictingToFull
# 0                30
# 1                21
# 2                16
# 3                30
# 4                74
# 5                48
# 6                62
# 7                61
# 8                37
# 9                45

# %%
weather.groupby('pedictedWeather').mean()['predictingToFull'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pedictedWeather'>

# %%
weather[weather["pedictedWeather"] == "Sunny"].mean()
# Out:
# /var/folders/nj/gz0dny390v752tt2hrd7484w0000gn/T/ipykernel_15062/1895556667.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   weather[weather["pedictedWeather"] == "Sunny"].mean()
# waterLevel          36.122507
# humidity            18.313390
# temperature          9.111111
# windSpeed           15.598291
# clouds              37.789174
# predictingToFull    37.649573
# dtype: float64

# %%
def convert_summary(col):
    return len(col)

# %%
# Need to find the predictingToFull when clouds given
weather_temp = weather[["waterLevel","humidity","temperature","windSpeed","clouds","predictingToFull"]]
weather_temp.head(12)
# Out:
#     waterLevel  humidity  temperature  windSpeed  clouds  predictingToFull
# 0            2         7           13         27      15                30
# 1            0        20            8         31      70                21
# 2           46        12            1         18      58                16
# 3           24        17            0         27      11                30
# 4           26         4           13         23      11                74
# 5           66         1            3         11       3                48
# 6            4        28           13         25      40                62
# 7           45        38           10          9      44                61
# 8           45         2           16         18      32                37
# 9           68        24            6         30      48                45
# 10          50        29           16         13      52                13
# 11          55        20           17         31      15                52

# %%
dummies = pd.get_dummies(weather["pedictedWeather"])
dummies.head(122)
# Out:
#      Clouds  Rains  Sunny
# 0         0      1      0
# 1         1      0      0
# 2         0      0      1
# 3         0      1      0
# 4         1      0      0
# ..      ...    ...    ...
# 117       0      0      1
# 118       0      0      1
# 119       1      0      0
# 120       0      0      1
# 121       0      0      1
#
# [122 rows x 3 columns]

# %%
weather_temp2 = pd.concat([weather_temp,dummies],axis=1)
weather_temp2.head(12)
# Out:
#     waterLevel  humidity  temperature  windSpeed  clouds  predictingToFull  \
# 0            2         7           13         27      15                30
# 1            0        20            8         31      70                21
# 2           46        12            1         18      58                16
# 3           24        17            0         27      11                30
# 4           26         4           13         23      11                74
# 5           66         1            3         11       3                48
# 6            4        28           13         25      40                62
# 7           45        38           10          9      44                61
# 8           45         2           16         18      32                37
# 9           68        24            6         30      48                45
# 10          50        29           16         13      52                13
# 11          55        20           17         31      15                52
#
#     Clouds  Rains  Sunny
# 0        0      1      0
# 1        1      0      0
# 2        0      0      1
# 3        0      1      0
# 4        1      0      0
# 5        1      0      0
# 6        0      0      1
# 7        1      0      0
# 8        1      0      0
# 9        1      0      0
# 10       0      0      1
# 11       1      0      0

# %%
# Spliting X (Independent Variables) and Y(predicting variable)

Y = weather_temp["predictingToFull"]
X = weather_temp2
# making Two dimensional array
# X = X.reshape(-1,1)
X
# Out:
#      waterLevel  humidity  temperature  windSpeed  clouds  predictingToFull  \
# 0             2         7           13         27      15                30
# 1             0        20            8         31      70                21
# 2            46        12            1         18      58                16
# 3            24        17            0         27      11                30
# 4            26         4           13         23      11                74
# ..          ...       ...          ...        ...     ...               ...
# 995          41        29            2          2      64                14
# 996           5        16            6          5      30                17
# 997          35         2            1         18       6                38
# 998          63        38           14          2      67                19
# 999          51         2            0         32      57                62
#
#      Clouds  Rains  Sunny
# 0         0      1      0
# 1         1      0      0
# 2         0      0      1
# 3         0      1      0
# 4         1      0      0
# ..      ...    ...    ...
# 995       0      1      0
# 996       0      0      1
# 997       0      0      1
# 998       0      1      0
# 999       0      1      0
#
# [1000 rows x 9 columns]

# %%
# Normalizing the X variables 
# check the x values should be between (-3  3)
#X.dropna()
x = (X >=0)
x.sum()

# prints the zero humidity
print(x.sum(),X.shape)
non_zero_humidity = X >= 0
print(non_zero_humidity.sum())
# Out:
# waterLevel          1000
# humidity            1000
# temperature         1000
# windSpeed           1000
# clouds              1000
# predictingToFull    1000
# Clouds              1000
# Rains               1000
# Sunny               1000
# dtype: int64 (1000, 9)
# waterLevel          1000
# humidity            1000
# temperature         1000
# windSpeed           1000
# clouds              1000
# predictingToFull    1000
# Clouds              1000
# Rains               1000
# Sunny               1000
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3)

# %%
X_test
# y_test
# Out:
#      waterLevel  humidity  temperature  windSpeed  clouds  predictingToFull  \
# 344           3        36            3         22      17                44
# 606           4        28            3         18      17                11
# 440          62         5            8         29      30                16
# 116          58        10            7         24      32                 9
# 752           6        16            7         25       2                74
# ..          ...       ...          ...        ...     ...               ...
# 138          62        15           16          6      64                23
# 97           14         9            9         31       0                56
# 931          53        32           16         31       0                16
# 726          23         1            6          1      71                20
# 725          49         6            3         28      57                28
#
#      Clouds  Rains  Sunny
# 344       0      0      1
# 606       0      1      0
# 440       1      0      0
# 116       0      0      1
# 752       0      0      1
# ..      ...    ...    ...
# 138       1      0      0
# 97        0      1      0
# 931       1      0      0
# 726       0      0      1
# 725       0      1      0
#
# [300 rows x 9 columns]

# %%
X_train.shape, y_train.shape
# Out:
# ((700, 9), (700,))

# %%
#print(X_train.head(10))
y_train.head(10)
# Out:
# 577     2
# 430     4
# 398    63
# 738     3
# 275    72
# 154    63
# 153    32
# 490    59
# 781    71
# 80     30
# Name: predictingToFull, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
X_train.shape,y_train.shape
# Out:
# ((700, 9), (700,))

# %%
from sklearn import tree

tree.plot_tree(model)
plt.show()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([44, 11, 16,  9, 74,  1, 23, 39, 30, 18, 51,  2, 72,  3, 73, 15,  8,
#        69,  7, 37, 21,  8, 40,  4, 68, 11, 73, 54, 15, 67, 34, 50, 60, 53,
#        13, 33, 41, 45, 69,  5, 43, 46,  4, 37, 72, 44,  7, 69, 62, 45, 39,
#        47, 35, 71, 56, 13, 72, 70, 74, 68, 61, 74, 73, 58, 48, 55, 70, 23,
#        12, 48, 21, 65,  8, 10,  7, 20, 71, 11, 49, 24, 69, 64, 48,  4, 18,
#        40,  5, 26, 45, 21, 19, 24, 55, 21, 16, 74, 47, 10, 51,  9, 39,  2,
#        43, 68, 13, 60,  9,  0, 72, 27, 39, 21,  7, 36, 66, 33,  7, 40, 34,
#        16, 34, 43, 59, 57, 69,  8, 47, 17, 71,  0, 64, 57,  0, 24, 29,  7,
#        14,  5, 71, 65, 20, 37, 26, 30, 15, 50, 31, 51,  2, 72, 22, 48, 63,
#        54, 39,  1, 23, 27, 27, 40, 14, 12, 20, 56, 21, 36, 61, 12, 61,  6,
#         5, 60, 30, 26, 17, 26, 60, 14, 21, 64, 63, 34, 49, 18, 27, 62, 52,
#        49,  6, 66, 57,  9, 25, 11, 66, 73,  8, 28, 39, 35, 34, 71,  1, 72,
#        71, 64, 37, 50, 22,  2, 27, 15, 64, 25, 68, 18, 72,  0,  2, 34, 12,
#        12, 59, 28, 14, 70, 13, 16, 59, 27,  3, 26, 27, 70, 32,  1, 48, 22,
#        40, 14, 67, 60, 18, 56, 73, 63, 11, 46, 45, 45, 31,  1, 55, 73, 59,
#        58, 25, 14, 31, 62, 29, 34,  5, 42, 30, 48,  1, 55, 68, 39, 38, 42,
#         6, 73, 56, 23, 15, 14, 63, 73,  3, 12, 33, 37, 42, 37, 62, 72, 63,
#        10, 51, 65, 27, 24, 63, 23, 56, 16, 20, 28])

# %%
y_predict = model.predict(X_test)

# %%
y_pred = y_predict.reshape(1,-1)
y_pred
# Out:
# array([[44, 11, 16,  9, 74,  1, 23, 39, 30, 18, 51,  2, 72,  3, 73, 15,
#          8, 69,  7, 37, 21,  8, 40,  4, 68, 11, 73, 54, 15, 67, 34, 50,
#         60, 53, 13, 33, 41, 45, 69,  5, 43, 46,  4, 37, 72, 44,  7, 69,
#         62, 45, 39, 47, 35, 71, 56, 13, 72, 70, 74, 68, 61, 74, 73, 58,
#         48, 55, 70, 23, 12, 48, 21, 65,  8, 10,  7, 20, 71, 11, 49, 24,
#         69, 64, 48,  4, 18, 40,  5, 26, 45, 21, 19, 24, 55, 21, 16, 74,
#         47, 10, 51,  9, 39,  2, 43, 68, 13, 60,  9,  0, 72, 27, 39, 21,
#          7, 36, 66, 33,  7, 40, 34, 16, 34, 43, 59, 57, 69,  8, 47, 17,
#         71,  0, 64, 57,  0, 24, 29,  7, 14,  5, 71, 65, 20, 37, 26, 30,
#         15, 50, 31, 51,  2, 72, 22, 48, 63, 54, 39,  1, 23, 27, 27, 40,
#         14, 12, 20, 56, 21, 36, 61, 12, 61,  6,  5, 60, 30, 26, 17, 26,
#         60, 14, 21, 64, 63, 34, 49, 18, 27, 62, 52, 49,  6, 66, 57,  9,
#         25, 11, 66, 73,  8, 28, 39, 35, 34, 71,  1, 72, 71, 64, 37, 50,
#         22,  2, 27, 15, 64, 25, 68, 18, 72,  0,  2, 34, 12, 12, 59, 28,
#         14, 70, 13, 16, 59, 27,  3, 26, 27, 70, 32,  1, 48, 22, 40, 14,
#         67, 60, 18, 56, 73, 63, 11, 46, 45, 45, 31,  1, 55, 73, 59, 58,
#         25, 14, 31, 62, 29, 34,  5, 42, 30, 48,  1, 55, 68, 39, 38, 42,
#          6, 73, 56, 23, 15, 14, 63, 73,  3, 12, 33, 37, 42, 37, 62, 72,
#         63, 10, 51, 65, 27, 24, 63, 23, 56, 16, 20, 28]])

# %%
y_test.head()
# Out:
# 344    44
# 606    11
# 440    16
# 116     9
# 752    74
# Name: predictingToFull, dtype: int64

# %%
test = pd.DataFrame(y_test)
test["y_predict"]= 0
test["y_predict"] = y_predict
test.head(20)
# Out:
#      predictingToFull  y_predict
# 344                44         44
# 606                11         11
# 440                16         16
# 116                 9          9
# 752                74         74
# 335                 1          1
# 852                23         23
# 383                39         39
# 392                30         30
# 789                17         18
# 499                51         51
# 476                 2          2
# 759                72         72
# 484                 3          3
# 373                73         73
# 70                 15         15
# 254                 8          8
# 39                 69         69
# 425                 7          7
# 967                37         37

# %%
weather.iloc[703]
# Out:
# waterLevel              37
# humidity                12
# temperature             16
# windSpeed                8
# clouds                  47
# pedictedWeather     Clouds
# predictingToFull        34
# Name: 703, dtype: object

# %%
from sklearn.metrics import explained_variance_score
variance = explained_variance_score(y_test,y_predict, multioutput='uniform_average')
variance
# Out:
# 0.9999747042528475

# %%
test_pred_decision_tree = model.predict([[23,32,22,38,12,75,1,0,0]])
# Out:
# /Users/thilangaattanayake/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
test_pred_decision_tree
# Out:
# array([74])

# %%
# model.predict_proba([[10,22,34,28,12,75,0,0,1]], check_input=True)

model.predict([[23,32,22,38,12,75,1,0,0]], check_input=True)
# Out:
# /Users/thilangaattanayake/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([74])
